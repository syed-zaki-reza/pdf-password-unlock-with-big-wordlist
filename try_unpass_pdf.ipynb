# %%
# !pip install pikepdf
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 7.7 MB/s
# ...

# %%
# !pip install lstpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''  """
# try 1

import lstpy
import pikepdf
from tqdm import tqdm

lines_per_file = 10000
smallfile = None
round = 1
with open("/content/drive/MyDrive/Upload For Public Use/lets open it/realuniq.lst", encoding='ISO-8859-1') as bigfile:
    for lineno, line in enumerate(bigfile):
        if lineno % lines_per_file == 0:
            if smallfile:
                smallfile.close()
            small_filename = 'small_file_{}.txt'.format(lineno + lines_per_file)
            smallfile = open(small_filename, "r")
            passwords = [ line.strip() for line in smallfile]
            print(f'round = {round}. passwords = {passwords}')
            round = round + 1
            for password in tqdm(passwords, "/content/drive/MyDrive/Upload For Public Use/lets open it/4_Analysis Principle and Risk Management -protected.pdf"):
                try:
                    # open PDF file
                    with pikepdf.open("/content/drive/MyDrive/Upload For Public Use/lets open it/4_Analysis Principle and Risk Management -protected.pdf", password=password) as pdf:
                        # Password decrypted successfully, break out of the loop
                        print("[+] Password found:", password)
                        break
                except pikepdf._qpdf.PasswordError as e:
                    # wrong password, just continue in the loop
                    continue
    if smallfile:
        smallfile.close()

"""  '''
# Out:
# '  """\n# try 1\n\nimport lstpy\nimport pikepdf\nfrom tqdm import tqdm\n\nlines_per_file = 10000\nsmallfile = None\nround = 1\nwith open("/content/drive/MyDrive/Upload For Public Use/lets open it/realuniq.lst", encoding=\'ISO-8859-1\') as bigfile:\n    for lineno, line in enumerate(bigfile):\n        if lineno % lines_per_file == 0:\n            if smallfile:\n                smallfile.close()\n            small_filename = \'small_file_{}.txt\'.format(lineno + lines_per_file)\n            smallfile = open(small_filename, "r")\n            passwords = [ line.strip() for line in smallfile]\n            print(f\'round = {round}. passwords = {passwords}\')\n            round = round + 1\n            for password in tqdm(passwords, "/content/drive/MyDrive/Upload For Public Use/lets open it/4_Analysis Principle and Risk Management -protected.pdf"):\n                try:\n                    # open PDF file\n                    with pikepdf.open("/content/drive/MyDrive/Upload For Public Use
# ...

# %%
import lstpy
import pikepdf
from tqdm import tqdm

# lines_per_file = 10000
with open("/content/drive/MyDrive/Upload For Public Use/lets open it/realuniq.lst", encoding='ISO-8859-1') as bigfile:
    for lineno, password in enumerate(bigfile):
        if (lineno > 112419100):
            print(f'lineno = {lineno}. password = {password}')        
            # for password in tqdm(passwords, "/content/drive/MyDrive/Upload For Public Use/lets open it/4_Analysis Principle and Risk Management -protected.pdf"):
            try:
                # open PDF file
                with pikepdf.open("/content/drive/MyDrive/Upload For Public Use/lets open it/4_Analysis Principle and Risk Management -protected.pdf", password=password) as pdf:
                    # Password decrypted successfully, break out of the loop
                    print("[+] Password found:", password)
                    break
            except pikepdf._qpdf.PasswordError as e:
                # wrong password, just continue in the loop
                continue
# Out:
# Streaming output truncated to the last 5000 lines.
# lineno = 115142870. password = 47642639
#
# lineno = 115142871. password = 4764264
#
# lineno = 115142872. password = 47642640
#
# lineno = 115142873. password = 476426401
#
# lineno = 115142874. password = 4764264021
#
# lineno = 115142875. password = 4764264076
#
# lineno = 115142876. password = 47642641
#
# lineno = 115142877. password = 4764264145
#
# lineno = 115142878. password = 47642642
#
# lineno = 115142879. password = 47642643
#
# lineno = 115142880. password = 4764264335
#
# lineno = 115142881. password = 47642644
#
# lineno = 115142882. password = 47642645
#
# lineno = 115142883. password = 47642646
#
# lineno = 115142884. password = 47642647
#
# lineno = 115142885. password = 47642648
#
# lineno = 115142886. password = 47642649
#
# lineno = 115142887. password = 4764265
#
# lineno = 115142888. password = 47642650
#
# lineno = 115142889. password = 47642651
#
# lineno = 115142890. password = 47642652
#
# ...
